# %% [markdown]
# Pandas:
#
# Pandas is an open-source data manipulation and analysis library for the Python programming language. It provides data structures for efficiently storing and manipulating large datasets and tools for working with structured data. The primary data structures in Pandas are:
#
# Series: A one-dimensional array-like object that can hold any data type. It is similar to a column in a spreadsheet or a single column in a DataFrame.
#
# DataFrame: A two-dimensional table of data with rows and columns. It can be thought of as a spreadsheet or a SQL table. It is one of the most commonly used data structures in Pandas.

# %%
import pandas as pd

# %%
# creating Series
s = pd.Series(['Priya', 'Kulkarni', 'Pandas', 'Numpy'])

print(s)
print(type(s))

#indexing
print(s[0])

#slicing
print(s[:2])

# selection of items in out of order manner
print(s[[1,3]])
# Out:
# 0       Priya
# 1    Kulkarni
# 2      Pandas
# 3       Numpy
# dtype: object
# <class 'pandas.core.series.Series'>
# Priya
# 0       Priya
# 1    Kulkarni
# dtype: object
# 1    Kulkarni
# 3       Numpy
# dtype: object

# %%
# boolean indexing
param = s!= 'Pandas'
print(s[param])
# Out:
# 0       Priya
# 1    Kulkarni
# 3       Numpy
# dtype: object

# %%
# converting dictionary to series
d = { 'n' :1 ,'r':4,'u':5,'y':2,'c':3}
print(d)
print(type(d))
# conversion
se = pd.Series(d)
print(se)
# indexing
print(se[['n','c']])
# boolean indexing
print(se[se>2])
#manipulation
se [se<3] = 2
print(se)
# Out:
# {'n': 1, 'r': 4, 'u': 5, 'y': 2, 'c': 3}
# <class 'dict'>
# n    1
# r    4
# u    5
# y    2
# c    3
# dtype: int64
# n    1
# c    3
# dtype: int64
# r    4
# u    5
# c    3
# dtype: int64
# n    2
# r    4
# u    5
# y    2
# c    3
# dtype: int64

# %% [markdown]
# #dataframe

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Pythonclass/Titanic.txt', sep='\t')

# %%
print(titanic.head())
# Out:
#   pclass    age   sex survived
# 0    1st  adult  male      yes
# 1    1st  adult  male      yes
# 2    1st  adult  male      yes
# 3    1st  adult  male      yes
# 4    1st  adult  male      yes

# %%
# each column is series
titanic['age']
# Out:
# 0       adult
# 1       adult
# 2       adult
# 3       adult
# 4       adult
#         ...
# 2196    adult
# 2197    adult
# 2198    adult
# 2199    adult
# 2200    adult
# Name: age, Length: 2201, dtype: object

# %%
# multiple column will give Dataframe
titanic[['age','pclass']]
# Out:
#         age pclass
# 0     adult    1st
# 1     adult    1st
# 2     adult    1st
# 3     adult    1st
# 4     adult    1st
# ...     ...    ...
# 2196  adult   crew
# 2197  adult   crew
# 2198  adult   crew
# 2199  adult   crew
# 2200  adult   crew
#
# [2201 rows x 2 columns]

# %%
# boolean indexing
titanic[ (titanic.age == 'child') & (titanic.pclass == '2nd')]
# Out:
#     pclass    age     sex survived
# 586    2nd  child    male      yes
# 587    2nd  child    male      yes
# 588    2nd  child    male      yes
# 589    2nd  child    male      yes
# 590    2nd  child    male      yes
# 591    2nd  child    male      yes
# 592    2nd  child    male      yes
# 593    2nd  child    male      yes
# 594    2nd  child    male      yes
# 595    2nd  child    male      yes
# 596    2nd  child    male      yes
# 597    2nd  child  female      yes
# 598    2nd  child  female      yes
# 599    2nd  child  female      yes
# 600    2nd  child  female      yes
# 601    2nd  child  female      yes
# 602    2nd  child  female      yes
# 603    2nd  child  female      yes
# 604    2nd  child  female      yes
# 605    2nd  child  female      yes
# 606    2nd  child  female      yes
# 607    2nd  child  female      yes
# 608    2nd  child  female      yes
# 609    2nd  child  female      yes

# %%
# slicing
titanic[320:325]
# Out:
#     pclass    age     sex survived
# 320    1st  child    male      yes
# 321    1st  child    male      yes
# 322    1st  child    male      yes
# 323    1st  child    male      yes
# 324    1st  child  female      yes

# %%
# groupingby groupby and aggregation function
by_age = titanic.groupby('age')
# count of each age category
by_age.size()
# Out:
# age
# adult    2092
# child     109
# dtype: int64

# %%
# Comparsion of male and female
print(titanic.groupby('sex').size())
# Out:
# sex
# female     470
# male      1731
# dtype: int64

# %%
# print the number of females and males survived
print(titanic.groupby(['survived','sex']).size())
# Out:
# survived  sex
# no        female     126
#           male      1364
# yes       female     344
#           male       367
# dtype: int64
